# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1),index = pd.date_range('2021-07-18',periods=1000),columns=['data'])
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(style ='r--',legend = True)
# Out:
# <AxesSubplot:>

# %%
df['data'].plot(style ='g--',legend=True,label='DATA')
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum()
# Out:
# 2021-07-18      0.588131
# 2021-07-19      1.485845
# 2021-07-20      2.377375
# 2021-07-21      3.193213
# 2021-07-22      3.229102
#                  ...
# 2024-04-08    495.812936
# 2024-04-09    496.568973
# 2024-04-10    496.868159
# 2024-04-11    497.129872
# 2024-04-12    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
#df.data.cumsum()
df['data1'] = df.data.cumsum()
df['data2'] = df['data'].apply(lambda x:x**3)
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  0.203433
# 2021-07-19  0.897714    1.485845  0.723458
# 2021-07-20  0.891531    2.377375  0.708613
# 2021-07-21  0.815837    3.193213  0.543014
# 2021-07-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  0.976749
# 2024-04-09  0.756037  496.568973  0.432145
# 2024-04-10  0.299186  496.868159  0.026781
# 2024-04-11  0.261712  497.129872  0.017926
# 2024-04-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(figsize=(5,5),title='Iris')
# Out:
# <AxesSubplot:title={'center':'Iris'}>

# %%
gf = df1.plot(figsize=(5,5),title='Iris')
gf.set_xlabel("This is my x axis")
gf.set_ylabel("This is my y axis")
# Out:
# Text(0, 0.5, 'This is my y axis')

# %%
df1.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df1.iloc[0][:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
#line
df1.iloc[0][:4].plot()
# Out:
# <AxesSubplot:>

# %%
df1.iloc[0][:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2 = sns.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
#bar
df3.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
#bar
#Another way
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#barh
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#histogram - frequency and occurence
#with the help of histogram we can draw the bell curve
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind = 'hist', stacked = True, bins = 100,title = 'hist of iris')
# Out:
# <AxesSubplot:title={'center':'hist of iris'}, ylabel='Frequency'>

# %%
df1.plot(kind = 'hist', stacked = True, bins = 100,title = 'hist of iris',orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'hist of iris'}, xlabel='Frequency'>

# %%
df1.hist(figsize=(10,10),color = 'green',alpha = .6)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
#scatterplot
df1.plot.scatter(x = 'sepal_width',y = 'petal_width',color = 'green',alpha = 0.6)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_length',y = 'petal_width',color = 'green',alpha = 0.6)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_length',y = 'petal_width',c='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_length',y = 'sepal_width',color = 'green',alpha = 0.6,label = 'IRIS')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x = 'sepal_length',y = 'sepal_width',color = 'green',alpha = 0.6,label = 'IRIS',s = 50)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x = 'sepal_length',y = 'sepal_width',c='petal_length',s=110)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
#hexbin
df1.plot.hexbin(x = 'sepal_length',y = 'sepal_width',gridsize = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  0.203433
# 2021-07-19  0.897714    1.485845  0.723458
# 2021-07-20  0.891531    2.377375  0.708613
# 2021-07-21  0.815837    3.193213  0.543014
# 2021-07-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  0.976749
# 2024-04-09  0.756037  496.568973  0.432145
# 2024-04-10  0.299186  496.868159  0.026781
# 2024-04-11  0.261712  497.129872  0.017926
# 2024-04-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]
d
# Out:
# data     0.588131
# data1    0.588131
# data2    0.203433
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
#pie chart
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
d.plot.pie(figsize =(5,5))
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
iris = df1.head(3).T
iris
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris.iloc[:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
iris.iloc[:4].plot.pie(subplots = True,figsize=(19,19))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris.iloc[:4].plot.pie(subplots = True,figsize=(19,19),fontsize = 15,autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
#Scatter matrix
pd.plotting.scatter_matrix(df1,figsize=(10,10),color='green')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
#kde - kernel density estimator
pd.plotting.scatter_matrix(df1,figsize=(10,10),color='green',diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...
